# %% [markdown]
# # 특허 DataSet 전처리

# %%
# 필요 라이브러리 모듈 import
import pandas as pd
import numpy as np
from pandas import DataFrame
from datetime import datetime

# %%
# 2차전지 csv 파일 불러오기
df = pd.read_csv('./data/new_secondary_cell.csv', engine='python')

# %%
# '출원인' 열에서 공동출원인을 나타내는 '|' 기호가 파이썬 연산자로 인식되어
# replace를 이용한 'and'로 문자열 교체
df['출원인'] = df['출원인'].str.replace('|',' and ')
df
# Out:
# <ipython-input-4-8bb390fcff14>:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df['출원인'] = df['출원인'].str.replace('|',' and ')
#          순서             출원번호        출원일자  \
# 0         1  10-2017-0149717  2017.11.10
# 1         2  10-2018-0092270  2018.08.08
# 2         3  10-2018-0048098  2018.04.25
# 3         4  10-2018-0156955  2018.12.07
# 4         5  10-2016-0157857  2016.11.25
# ...     ...              ...         ...
# 63959  3877  10-2001-0018267  2001.04.06
# 63960  3878  10-2001-0016618  2001.03.29
# 63961  3879  10-2010-0071646  2010.07.23
# 63962  3880  10-2010-0070581  2010.07.21
# 63963  3881  10-2011-0073720  2011.07.25
#
#                                                      출원인  \
# 0                             주식회사 디에이테크놀로지(경기도 화성시 ...)
# 1                           주식회사 엘지에너지솔루션(서울특별시 영등포구...)
# 2                           주식회사 엘지에너지솔루션(서울특별시 영등포구...)
# 3                     도요타 지도샤(주)(일본국 아이치켄 도요타시 도요타쵸 *반지)
# 4                                  (주)이티에스(충청남도 아산시 ...)
# ...                                                  ...
# 63959                           주식회사하나엔지니어링(경기도 양주시 ...)
# 63960                           한국에너지기술연구원(대전광역시 유성구...)
# 63961                      주식회사 메타바이오메드(충청북도 청주시 흥덕구...)
# 63962                           삼성전자주식회사(경기도 수원시 영통구...)
# 63963  시스멕스 가부시키가이샤(일본국 효고켄 고오베시 쥬오쿠 와키노하마 카이간 도오리 *-...
#
#                                                    발명의명칭        공고일자  \
# 0      이차전지 셀의 전극리드 성형장치(Lead Bending Machine for Sec...  2019.09.09
# 1      발광물질을 포함하는 리드필름을 구비한 이차전지 및 이차전지의 불량 검사 방법(Sec...         NaN
# 2      이차 전지 정압 지그 및 이를 이용한 이차 전지 내부 압력 조절 방법(SECONDA...  2021.06.07
# 3      비수전해액 이차 전지 및 비수전해액 이차 전지의 제조 방법(NONAQUEOUS EL...  2020.11.05
# 4      이차전지 제조장비의 전해액 주입장치(Electrolyte injection appa...  2017.07.04
# ...                                                  ...         ...
# 63959  저저항 투명도전성 복층 박막용 조성물, 이의 제조방법 및이를 포함하는 제품(Comp...  2003.05.22
# 63960  전기흡착 방식의 담수화방법 및 장치(Desalination System and Re...  2004.08.04
# 63961  다기능 전동식 치근관 충진장치(An electromotive stuffing dev...  2012.02.15
# 63962  비주얼 페어링 수행 시스템 및 방법(SYSTEM AND METHOD FOR VISU...  2017.01.02
# 63963                검체처리장치(SAMPLE PROCESSING APPARATUS)  2012.12.11
#
#              공개일자        등록일자  \
# 0      2019.05.20  2019.09.03
# 1      2020.02.18         NaN
# 2      2019.11.04  2021.05.31
# 3      2019.06.19  2020.10.30
# 4      2017.06.07  2017.06.27
# ...           ...         ...
# 63959  2002.10.18  2003.05.06
# 63960  2002.10.11  2004.07.22
# 63961  2012.02.02  2012.01.19
# 63962  2011.08.03  2016.12.27
# 63963  2012.02.13  2012.12.05
#
#                                                      발명자  \
# 0                                       정영태(경기도 화성시 ...)
# 1                                      황조연(대전광역시 유성구...)
# 2      윤종건(대전광역시 유성구...)|하회진(대전광역시 유성구...)|이정범(대전광역시 ...
# 3      이시이 겐타(일본국 아이치켄 도요타시 ...)|모리타 마사히로(일본국 아이치켄 도요...
# 4                                   이유성(충청남도 천안시 동남구...)
# ...                                                  ...
# 63959                   김은호(경기도고양시일산구...)|김기봉(경기도양주군...)
# 63960  김동국(대전광역시유성구...)|김종휘(대전광역시유성구...)|임장순(경기도군포시.....
# 63961  김준형(충청북도 청원군...)|김도연(충청북도 청주시 흥덕구...)|김기섭(충청북도...
# 63962  옥스 에드워드(이스라엘, 배트 얌, 라지엘 스트리트 **a)|톨레대노 에이얼(이스라...
# 63963  기타가와 노부히로(일본국 효고켄 고오베시 쥬오쿠 와키노하마 카이간 도오리 *-*-*...
#
#                                                       요약
# 0      본 발명은 이차전지의 제조 과정에서 전극조립체의 전극리드를 Z 형태로 2단으로 절곡...
# 1      양극과 음극 사이에 분리막이 개재되어 있는 구조의 전극조립체, 상기 전극조립체의 장...
# 2      본 발명의 일 실시예에 따른 이차 전지 정압 지그는 전지셀의 양면에 배치되어 상기 ...
# 3      본 발명에 의해, SEI막이 부극 활물질의 표면에 형성되어 있는 비수전해액 이차 전...
# 4      본 발명은 전기자동차 등에 사용되는 이차전지를 제조하는 공정에서 셀의 내부에 전해액...
# ...                                                  ...
# 63959  본 발명은 저저항 투명도전성 복층 박막용 조성물, 이의 제조방법 및 이를 포함하는 ...
# 63960  본 발명은 전기화학 축전 또는 흡착방식의 담수화시스템 및 재생방법에 관한 것으로, ...
# 63961  본 발명은 전동식 치근관 충진장치에 관한 것으로, 더욱 상세하게는 손상된 치근관의 ...
# 63962  무선 장치들 사이에 비주얼 페어링을 위한 시스템 및 방법에 있어서, 제1 소프트웨어...
# 63963  하부의 외측에 마련된 오목부를 구비하는 제1 종류의 검체용기와 당해 오목부를 구비하...
#
# [63964 rows x 10 columns]

# %%
# '종목코드' column 생성
df.insert(10,'종목코드', 0, allow_duplicates=False)

# %%
# data의 대략적인 정보 확인
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63964 entries, 0 to 63963
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   순서      63928 non-null  object
#  1   출원번호    63892 non-null  object
#  2   출원일자    63892 non-null  object
#  3   출원인     63892 non-null  object
#  4   발명의명칭   63892 non-null  object
#  5   공고일자    43766 non-null  object
#  6   공개일자    56950 non-null  object
#  7   등록일자    43845 non-null  object
#  8   발명자     63892 non-null  object
#  9   요약      63878 non-null  object
#  10  종목코드    63964 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 5.4+ MB

# %%
# 출원인 columns에서 특정 기업 접근
# NaN이 존재하는 경우 False로 치환
df[df['출원인'].str.contains('삼성에스디아이', na=False)]
# Out:
#          순서             출원번호        출원일자                           출원인  \
# 93       94  10-2006-0105094  2006.10.27  삼성에스디아이 주식회사(경기도 용인시 기흥구...)
# 118     119  10-2010-0108353  2010.11.02  삼성에스디아이 주식회사(경기도 용인시 기흥구...)
# 201     202  10-2014-0083228  2014.07.03  삼성에스디아이 주식회사(경기도 용인시 기흥구...)
# 218     219  10-2020-0022999  2020.02.25  삼성에스디아이 주식회사(경기도 용인시 기흥구...)
# 270     271  10-2017-0090469  2017.07.17  삼성에스디아이 주식회사(경기도 용인시 기흥구...)
# ...     ...              ...         ...                           ...
# 52571  2502  10-2003-0051681  2003.07.25  삼성에스디아이 주식회사(경기도 용인시 기흥구...)
# 52572  2503  10-2002-0039495  2002.07.08  삼성에스디아이 주식회사(경기도 용인시 기흥구...)
# 52573  2504  10-2002-0005435  2002.01.30  삼성에스디아이 주식회사(경기도 용인시 기흥구...)
# 52574  2505  10-2001-0074375  2001.11.27  삼성에스디아이 주식회사(경기도 용인시 기흥구...)
# 52575  2506  10-2003-0051659  2003.07.25  삼성에스디아이 주식회사(경기도 용인시 기흥구...)
#
#                                                    발명의명칭        공고일자  \
# 93               파우치형 이차전지(Pouch type secondary battery)  2013.09.13
# 118    리튬 이차전지용 양극 활물질 및 이의 제조방법(POSITIVE ACTIVE MATE...  2013.04.18
# 201    리튬 이차전지용 전해질, 및 이를 포함하는 리튬 이차전지(Electrolyte fo...         NaN
# 218                전고체 이차전지(All Solid secondary battery)         NaN
# 270                    이차전지 모듈(Secondary Battery Module)         NaN
# ...                                                  ...         ...
# 52571  다결정 실리콘 박막 트랜지스터를 포함하는 평판 표시 소자(FLAT PANEL DIS...  2006.01.20
# 52572  티에프티용 다결정 실리콘 박막 및 이를 사용한 디바이스(POLYSILICON THI...  2005.04.15
# 52573  투명도전막의 투과도 변형방법(Method of Varying Transmittanc...  2005.04.15
# 52574  박막 트랜지스터용 다결정 실리콘 박막 및 이를 사용한디바이스(POLYSILICON ...  2005.04.15
# 52575  다결정 실리콘 박막 트랜지스터를 포함하는 평판 표시 소자(FLAT PANEL DIS...  2006.01.20
#
#              공개일자        등록일자  \
# 93     2008.05.02  2013.09.06
# 118    2012.05.10  2013.04.12
# 201    2015.01.16  2021.09.27
# 218    2021.09.02         NaN
# 270    2019.01.25         NaN
# ...           ...         ...
# 52571  2005.02.02  2006.01.06
# 52572  2004.01.16  2005.04.08
# 52573  2003.06.09  2005.04.08
# 52574  2003.06.02  2005.04.08
# 52575  2005.02.02  2006.01.06
#
#                                                      발명자  \
# 93                                    이찬희(경기 용인시 기흥구...)
# 118    이준형(경기 용인시 기흥구...)|안드레이 크바샤(경기 용인시 기흥구 공세동 ***...
# 201    에고로프 블라디미르(경기도 용인시 기흥구 공세로 ***-** (공세동))|신우철(경...
# 218    김진규(경기도 용인시 기흥구...)|이규린(경기도 용인시 기흥구...)|이정혜(경기...
# 270    이준형(경기도 용인시 기흥구...)|한만석(경기도 용인시 기흥구...)|박명국(경기...
# ...                                                  ...
# 52571  박지용(경기도수원시팔달구...)|이을호(경기도용인시...)|구재본(경기도용인시......
# 52572  이기용(경기도수원시팔달구...)|박지용(경기도수원시권선구...)|소우영(경기도수원시...
# 52573                  박상일(서울특별시양천구...)|김창수(서울특별시금천구...)
# 52574                                  이기용(경기도수원시팔달구...)
# 52575  박지용(경기도수원시팔달구...)|이을호(경기도용인시...)|구재본(경기도용인시......
#
#                                                       요약  종목코드
# 93     본 발명은 파우치형 이차전지에 관한 것으로서, 더욱 상세하게는 외장 팩을 포함해 이...     0
# 118    리튬을 가역적으로 인터칼레이션 및 디인터칼레이션할 수 있는 화합물을 포함하는 코어;...     0
# 201    실리콘 함유 화합물은 리튬 이차전지의 상온 및 고온 수명 특성, 및/또는 고온 안정...     0
# 218    양극; 음극; 및 상기 양극과 상기 음극 사이에 배치된 고체전해질층을 포함하고, 상...     0
# 270    일방향으로 정렬된 다수개의 배터리 셀, 다수개의 배터리 셀 사이에 개재되어 배터리 ...     0
# ...                                                  ...   ...
# 52571  본 발명은 다결정 실리콘 박막 트랜지스터를 포함하는 평판 표시 소자에 관한 것으로,...     0
# 52572  본 발명은 TFT에 사용되는 다결정 실리콘 박막 및 이를 사용하여 제조되는 디바이스...     0
# 52573  본 발명은 표시소자의 화소전극 또는 공통전극 등으로 사용되는 투명도전막의 투과도 특...     0
# 52574  본 발명은 TFT에 사용되는 다결정 실리콘 박막 및 이를 사용하여 제조되는 디바이스...     0
# 52575  본 발명은 다결정 실리콘 박막 트랜지스터를 포함하는 평판 표시 소자에 관한 것으로,...     0
#
# [4092 rows x 11 columns]

# %%
total_dict = {
    '엠케이전자':'A033160',
    '이엔에프테크놀로지':'A102710',
    '씨아이에스':'A222080',
    '솔브레인홀딩스':'A036830',
    '휘닉스소재':'A050090',
    '대주전자재료':'A078600',
    '엘아이에스x':'A138690',
    '애경유화':'A161000',
    '삼화콘덴서':'A001820',
    '포스코_':'A005490',
    '스카이이앤엠':'A131100',
    '램테크놀러지':'A171010',
    '명성티엔에스':'A257370',
    '코스모화학':'A005420',
    '상아프론테크':'A089980',
    '필옵틱스':'A161580',
    '에코프로에이치엔x':'A383310',
    '에스케이이노베이션':'A096770',
    '에스케이씨':'A011790',
    '엘지화학':'A051910',
    '포스코케미칼':'A003670',
    '이엔드디':'A101360',
    '켐트로스':'A220260',
    '후성_':'A093370',
    '원익피앤이':'A131390',
    '피엔티':'A137400',
    '디에이테크놀로지':'A196490',
    '주_엔에스':'A217820',
    '신흥에스이씨':'A243840',
    '에코프로비엠':'A247540',
    '엠플러스':'A259630',
    '티에스아이_':'A277880',
    '상신이디피':'A091580',
    '에코프로':'A086520',
    '엘앤에프':'A066970',
    '일진머티리얼즈':'A020150',
    '삼성에스디아이':'A006400',
    '에스케이아이이테크놀로지':'A361610',
    '코스모신소재':'A005070',
    '천보':'A278280',
    '엘지에너지솔루션':'A051910' # lg화학과 동일
}

# {기업 : 종목코드} 딕셔너리로 출원인에 해당하면 종목코드 입력
for key, code in total_dict.items():
    df.loc[df['출원인'].str.contains(f'{key}', na=False), '종목코드'] = f'{code}'
    

# 확인
df[df['출원인'].str.contains('에스케이아이이테크놀로지', na=False)]
# Out:
#          순서             출원번호        출원일자  \
# 1140   1141  10-2017-0134395  2017.10.17
# 1272   1273  10-2017-0167299  2017.12.07
# 3517   3518  10-2017-0161609  2017.11.29
# 6090   리튬이차전지용 분리막 및 이를 포함하는 리튬이차전지(Separator for lit...         NaN
# 8192   리튬 이차 전지용 분리막, 및 이를 포함하는 리튬 이차 전지(SEPARATOR FO...         NaN
# 8361   이차전지용 분리막 및 이를 이용한 전기화학소자(SEPARATOR FOR SECOND...         NaN
# 8394   이차전지용 분리막 및 이를 이용한 전기화학소자(SEPARATOR FOR SECOND...         NaN
# 8395   이차전지용 분리막 및 이를 이용한 전기화학소자(SEPARATOR FOR SECOND...         NaN
# 9582   이차 전지용 다공성 분리막 및 이의 제조방법(Separator for seconda...         NaN
# 9661   이차전지용 복합 분리막(COMPOSITE MEMBRANE FOR SECONDARY ...         NaN
# 10215  소수성 표면을 갖는 배터리용 세퍼레이터 및 그 제조방법(SEPARATOR FOR S...         NaN
# 10661  리튬 이차전지용 분리막 및 그의 제조방법(Separator using lithium...         NaN
# 11754  접착성과 통기성이 우수한 이차전지용 분리막 및 이의 제조방법(Strong adhes...         NaN
# 11957  리튬 이차전지용 융착형 복합 분리막 및 이의 제조방법(Adhesive and mul...         NaN
# 11976  리튬 이차전지용 복합 분리막 및 이의 제조방법(Multi-layered lithiu...         NaN
# 16560  내열성 및 전기화학적 안정성이 우수한 세라믹 코팅 세퍼레이터 및 이의 제조방법(Ce...  2021.02.24
# 17741  다공성 복합 분리막 및 이를 포함하는 전기화학소자(POROUS COMPOSITE S...         NaN
# 19212  내열성 및 전해액 함침성이 우수한 세퍼레이터(SEPARATOR HAVING EXCE...         NaN
# 19816  폴리이미드 미세다공막 및 그 제조 방법(Microporous Polyimide Fi...         NaN
# 19981  내열성 및 전기화학적 안정성이 우수한 복합 미세다공막 및 이의 제조방법(micro-...  2019.10.23
# 21929  강한 층간 접착력을 갖는 다층 복합 분리막의 제조방법(Manufacturing me...         NaN
# 25606  폴리이미드 적층체와 그 제조방법 및 태양전지(POLYIMIDE LAMINATE, M...  2021.07.23
# 26434  고내열성 미세다공막 및 이의 제조 방법(High Temperature Resista...         NaN
# 30223  미세다공막의 제조방법(MANUFACTURING METHOD OF MICROPOROU...         NaN
# 30239  폴리올레핀계 다층 복합 다공막의 제조방법(Manufacturing method wi...  2021.09.08
# 30425  복합분리막 및 그의 제조방법(Composite Separator and manufa...         NaN
# 30558  초광폭 연속 코팅 장치 및 이를 이용한 분리막의 제조방법(Ultra large-wi...         NaN
# 31391  다공성 복합 분리막 및 이의 제조방법(POROUS COMPOSITE SEPARATO...         NaN
# 52204  폴리이미드 전구체, 이로부터 제조된 폴리이미드 및 이를 포함하는 폴리이미드 필름(P...  2021.06.23
# 56429  폴리이미드 복합기판의 제조방법 및 이로 제조된 폴리이미드 복합기판(MANUFACTU...  2021.02.26
# 61583  폴리이미드 복합체 필름 구조 및 제조 공정(Structure of Polyimide...  2020.09.02
#
#              공개일자        등록일자  \
# 1140   2019.04.25         NaN
# 1272   2019.06.17         NaN
# 3517   2019.06.07         NaN
# 4878   2017.06.12         NaN
# 4990   2016.11.23         NaN
# 6090   2017.10.20         NaN
# 11957  본 발명은 수명 및 안전성 향상 효과가 우수한 리튬 이차전지용 복합 분리막 및 이의...  A361610
# 11976  본 발명은 전지의 수명 및 안전성 향상 효과가 우수한 리튬 이차전지용 복합 분리막 ...  A361610
# 16560  본 발명은 이차전지용 세퍼레이터에 관한 것으로써, 실란 커플링 에이전트로 표면 처리...  A361610
# 17741  본 발명은 다공성 복합 분리막 및 이를 포함하는 전기화학소자에 관한 것으로, 보다 ...  A361610
# 19212  본 발명은 양극과 음극 사이에 개재되는 전지용 세퍼레이터, 전지용 세퍼레이터의 제조...  A361610
# 19816  본 발명은 리튬이온 이차전지용 세퍼레이터로 사용될 수 있는 우수한 강도, 투과도, ...  A361610
# 19981  본 발명은 복합 미세다공막 및 이의 제조방법에 관한 것으로, 고온에서의 열 안정성을...  A361610
# 21929  본 발명은 특정한 폴리올레핀계 수지 및 폴리불화비닐리덴계 수지를 사용한 공압출 과정...  A361610
# 25606  본 발명은 기재; 상기 기재의 일면에 형성된 제1 폴리이미드층; 및 상기 기재의 타...  A361610
# 26434  본 발명은 아미드 결합 및 이미드 결합을 포함하는 고분자, 유기용매가 증발함에 따라...  A361610
# 30223  본 발명은 미세다공막의 제조방법에 관한 것으로, 더욱 구체적으로 내열성 및 투과도가...  A361610
# 30239  본 발명은 a) 폴리올레핀 수지와 다일루언트를 포함하는 조성물을 시트로 성형하는 단...  A361610
# 30425  본 발명은 다공성 고분자 기재; 상기 다공성 고분자 기재의 표면에 형성되는 ALD ...  A361610
# 30558  본 발명은 연속 공정에 적용되는 초광폭 코팅 장치에 관한 것이다. 보다 상세하게는 ...  A361610
# 31391  본 발명은 섬유로 이루어지는 다공성 지지체의 섬유들 사이에 형성된 마이크로 사이즈의...  A361610
# 52204  본 발명에 따른 폴리이미드 전구체는 안정적인 공중합 폴리아믹산 용액의 제조가 가능하...  A361610
# 56429  본 발명은 폴리이미드 복합기판의 제조방법 및 이로 제조된 폴리이미드 복합기판에 관한...  A361610
# 61583  본 발명은 플렉시블 폴리이미드 복합필름에 관한 것으로, 보다 구체적으로 유리섬유를 ...  A361610

# %%
# 데이터프레임 저장 (.gz를 통해 압축저장 가능)
df.to_csv(f'./data/new_secondary_cell_pluscode.csv', index=False, encoding='utf-8-sig')

# %%
# 2차전지 pulscode.csv 파일 불러오기
df = pd.read_csv('./data/new_secondary_cell_pluscode.csv', engine='python')

# %%
# 종목코드 = 0인 데이터 즉, 사용하지 않는 데이터 삭제
df.drop(df[df['종목코드'] == '0'].index, inplace=True)
df
# Out:
#          순서             출원번호        출원일자  \
# 0         1  10-2017-0149717  2017.11.10
# 1         2  10-2018-0092270  2018.08.08
# 2         3  10-2018-0048098  2018.04.25
# 13       14  10-2005-0032926  2005.04.20
# 14       15  10-2014-0001124  2014.01.06
# ...     ...              ...         ...
# 63329  3247  10-2010-0026181  2010.03.24
# 63433  3351  10-2009-0082291  2009.09.02
# 63671  3589  10-2007-0104105  2007.10.16
# 63674  3592  10-2007-0096477  2007.09.21
# 63758   917  10-2019-0171870  2019.12.20
#
#                                                      출원인  \
# 0                             주식회사 디에이테크놀로지(경기도 화성시 ...)
# 1                           주식회사 엘지에너지솔루션(서울특별시 영등포구...)
# 2                           주식회사 엘지에너지솔루션(서울특별시 영등포구...)
# 13                              주식회사 엘지화학(서울특별시 영등포구...)
# 14                              주식회사 엘지화학(서울특별시 영등포구...)
# ...                                                  ...
# 63329                        삼화콘덴서공업주식회사(경기도 용인시 처인구...)
# 63433                       에스케이이노베이션 주식회사(서울특별시 종로구...)
# 63671  에스케이이노베이션 주식회사(서울특별시 종로구...) and 한국과학기술원(대전광역시...
# 63674                           주식회사 엘지화학(서울특별시 영등포구...)
# 63758  한국전자기술연구원(경기도 성남시 분당구...) and (주)포스코케미칼(경상북도 포...
#
#                                                    발명의명칭        공고일자  \
# 0      이차전지 셀의 전극리드 성형장치(Lead Bending Machine for Sec...  2019.09.09
# 1      발광물질을 포함하는 리드필름을 구비한 이차전지 및 이차전지의 불량 검사 방법(Sec...         NaN
# 2      이차 전지 정압 지그 및 이를 이용한 이차 전지 내부 압력 조절 방법(SECONDA...  2021.06.07
# 13     압전 센서가 내장된 이차전지 모듈(Secondary Battery Module Ha...  2009.03.17
# 14     금속 코팅된 고분자 집전체를 갖는 케이블형 이차전지(Cable Type Second...  2015.06.22
# ...                                                  ...         ...
# 63329  전기화학 커패시터용 망간산화물 나노 입자 제조방법(Method for prepari...  2012.11.07
# 63433  에틸렌 공중합체 및 이의 제조방법(Ethylene copolymer and a me...  2012.06.05
# 63671  전압 센서와 전하 균일 장치가 결합된 배터리 운용 시스템(Battery Manage...  2012.01.25
# 63674  광학필름 및 이의 제조방법(OPTICAL FILMS AND METHOD FOR FA...  2011.01.19
# 63758  리튬이온 이차전지용 음극 및 이를 포함하는 리튬 이차전지(NEGATIVE ELECT...         NaN
#
#              공개일자        등록일자  \
# 0      2019.05.20  2019.09.03
# 1      2020.02.18         NaN
# 2      2019.11.04  2021.05.31
# 13     2006.10.25  2009.03.11
# 14     2014.02.24  2015.06.16
# ...           ...         ...
# 63329  2011.09.30  2012.10.31
# 63433  2010.03.22  2012.05.25
# 63671  2009.04.21  2012.01.13
# 63674  2009.03.25  2011.01.13
# 63758  2021.07.01         NaN
#
#                                                      발명자  \
# 0                                       정영태(경기도 화성시 ...)
# 1                                      황조연(대전광역시 유성구...)
# 2      윤종건(대전광역시 유성구...)|하회진(대전광역시 유성구...)|이정범(대전광역시 ...
# 13                     윤여원(대전광역시 서구...)|정도양(경기도 화성시 ...)
# 14     권요한(대전광역시 유성구...)|김기태(대전광역시 유성구...)|김제영(대전광역시 ...
# ...                                                  ...
# 63329  오영주(서울특별시 서초구...)|윤중락(경기 용인시 처인구...)|이종협(서울특별시...
# 63433  신대호(대전광역시 유성구...)|심춘식(대전광역시 유성구...)|정지수(대전광역시 ...
# 63671  문건우(대전광역시 유성구...)|박홍선(대전광역시 유성구...)|김철호(대전광역시 ...
# 63674  강병일(대전 유성구...)|한창훈(대전 유성구...)|이대우(부산 사하구...)|서...
# 63758  우정규(경상북도 포항시 남구...)|김용중(경상북도 포항시 남구...)|유승재(경북...
#
#                                                       요약     종목코드
# 0      본 발명은 이차전지의 제조 과정에서 전극조립체의 전극리드를 Z 형태로 2단으로 절곡...  A196490
# 1      양극과 음극 사이에 분리막이 개재되어 있는 구조의 전극조립체, 상기 전극조립체의 장...  A051910
# 2      본 발명의 일 실시예에 따른 이차 전지 정압 지그는 전지셀의 양면에 배치되어 상기 ...  A051910
# 13     본 발명은 다수의 단위전지가 적층되어 있는 이차전지 모듈에 있어서, 방열을 위한 유...  A051910
# 14     본 발명은 소정 형상의 수평 단면을 가지는 집전체 및 상기 집전체의 표면에 형성된 ...  A051910
# ...                                                  ...      ...
# 63329  본 발명은 상온에서 pH(hydrogen exponent) 조절만을 통하여 높은 정...  A001820
# 63433  본 발명은 에틸렌 공중합체 및 이의 제조방법에 관한 것으로, 구체적으로는 직렬 또는...  A096770
# 63671  본 발명의 배터리 운용 장치는 직렬 연결된 복수개의 배터리로 구성된 배터리 모듈; ...  A096770
# 63674  본 발명은 i) 아크릴계 수지, 및 ii) 코어-쉘 타입의 그라프트 공중합체로서, ...  A051910
# 63758  본 개시는 Si계 모재와 코팅물질을 용매에 침지하여 혼합물 용액을 준비하는 단계; ...  A003670
#
# [16837 rows x 11 columns]

# %%
# 데이터프레임 저장 (.gz를 통해 압축저장 가능)
df.to_csv(f'./data/new_secondary_cell_pluscode_wonoise.csv', index=False, encoding='utf-8-sig')

# %% [markdown]
# 출원인이 중복인 경우 '종목코드'에 직접 입력(총 40건)
#
# -> new_secondary_cell_pluscode_wonoise_re.csv 생성

# %%
# 2차전지 csv 파일 불러오기
df = pd.read_csv('./data/new_secondary_cell_pluscode_wonoise_re.csv', engine='python')

# %%
# datetime을 이용해 출원날짜 데이터 형식 변경
df['출원일자'] = pd.to_datetime(df['출원일자'])

# '출원년월' column 생성
df.insert(3,'출원년월', 0, allow_duplicates=False)

# '출원년월' column에 %Y-%m 형식으로 변경
df['출원년월'] = df['출원일자'].dt.strftime('%Y-%m')
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-17cf0c48705c> in <module>
#       3
#       4 # '출원년월' column 생성
# ----> 5 df.insert(3,'출원년월', 0, allow_duplicates=False)
#       6
#       7 # '출원년월' column에 %Y-%m 형식으로 변경
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    3761         self._ensure_valid_index(value)
#    3762         value = self._sanitize_column(column, value, broadcast=False)
# -> 3763         self._mgr.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3764
#    3765     def assign(self, **kwargs) -> DataFrame:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value, allow_duplicates)
#    1189         if not allow_duplicates and item in self.items:
#    1190             # Should this be a different kind of error??
# -> 1191             raise ValueError(f"cannot insert {item}, already exists")
#    1192
#    1193         if not isinstance(loc, int):
#
# ValueError: cannot insert 출원년월, already exists

# %%
# 데이터프레임 저장 (.gz를 통해 압축저장 가능)
df.to_csv(f'./data/new_secondary_cell_pluscode_wonoise_re.csv', index=False, encoding='utf-8-sig')
